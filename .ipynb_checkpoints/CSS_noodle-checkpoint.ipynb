# %% [markdown]
# Load in the predictions. These are derived from dotting the gaussian function and the timeseries data.

# %%
import dill
def load(filename):
	input_file = open(filename, 'rb')
	obj = dill.load(input_file)
	return obj
import os

import matplotlib.pyplot as plt

# %%
predictions=load(os.path.join('/Volumes/BAHAMUT/OUTPUT/CF','tcR_32.pkl'))

# %%
predictions.shape
# Out:
# (10, 1327, 120)

# %% [markdown]
# We have a prediction timeseries for each size and each vertex (size,vertex,time)

# %%
import numpy as np
exampdat=np.copy(predictions[6,34,:])
plt.plot(exampdat)

# %% [markdown]
# If we apply a power transformation less than 1 to this data, we will get a bunch of na's

# %%
plt.plot(exampdat**0.2)
# Out:
# /Users/nicholashedger/anaconda2/envs/py3env/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in power
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# The solution people usually go for is to add a constant first to prevent this.

# %%
exampdat_r=(exampdat+1-np.min(exampdat))

# %%
plt.plot(exampdat_r)

# %% [markdown]
# Now, so far as I can tell, I should basically follow from this line onwards, with the exception that I don't have to convolve with any hrf. https://github.com/kdesimone/popeye/blob/master/popeye/css.py#L65
#
# Here, they have a linearly derived prediction, they raise it to a power and then normalise it.

# %%
def compress(signal,pwr):
    signal1=signal**pwr
    signal2 = (signal1 - np.mean(signal1)) / np.mean(signal1)
    return signal2

# %%
x=compress(exampdat_r,0.5)
y=compress(exampdat_r,0.1)
z=compress(exampdat_r,0.05)

# %%
fig = plt.figure(figsize=(17, 6)) 

plt.plot(x,'r')
plt.plot(y,'b')
plt.plot(z,'g')

# %%
fig = plt.figure(figsize=(17, 6)) 

plt.plot(stats.zscore(x),'r')
plt.plot(stats.zscore(y),'b')
plt.plot(stats.zscore(z),'g')
