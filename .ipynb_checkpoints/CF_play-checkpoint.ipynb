# %%
import matplotlib.pyplot as plt
import numpy as np
import cortex
import cortex.polyutils
import os
import popeye


from joblib import Parallel, delayed
from numpy import exp, linspace, random
from matplotlib import gridspec
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import scipy
from scipy import stats

# %% [markdown]
# Surface database stuff.

# %%
subject='02'
left, right = cortex.db.get_surf(subject, 'fiducial')


left_surface = cortex.polyutils.Surface(left[0], left[1])
right_surface = cortex.polyutils.Surface(right[0], right[1])

# %%
import dill
def load(filename):
	input_file = open(filename, 'rb')
	obj = dill.load(input_file)
	return obj

# %% [markdown]
# Load in the data. This is a big dictionary from my prf model fitting. Take just the left hemisphere for now.

# %%
dump_path='/Volumes/BAHAMUT/OUTPUT/FULL'

DATA=load(os.path.join(dump_path,'DICTS','02_prf.pkl'))

sframe=DATA['shortframe']
sframeL=sframe[0:163842]

# %%
sframeL.head()
# Out:
#           R2      sigma  isigma        ecc  iecc         ang  iang          X  \
# 0  27.695471  10.000000     0.0   4.853912   0.0  303.864723   0.0  -4.030473
# 1  56.418604   2.472724     0.0   0.632930   0.0  163.553058   0.0   0.179200
# 2   4.057080   0.564935     0.0  30.484376   0.0  271.545341   0.0 -30.473289
# 3   1.943642   1.174882     0.0  50.340255   0.0  173.334591   0.0   5.843050
# 4  44.977633  10.000000     0.0  28.175164   0.0  326.041273   0.0 -15.738522
#
#            Y  ROI  idx
# 0   2.704765  0.0  0.0
# 1  -0.607032  0.0  1.0
# 2   0.822103  0.0  2.0
# 3 -50.000000  0.0  3.0
# 4  23.369613  0.0  4.0

# %%
DATA=None

# %% [markdown]
# Also import the data that the prfs were fit to.

# %%
BIGDATAL=load('/Volumes/BAHAMUT/DUMP/BIGLHEM.pkl')

# %%
BIGDATAL.shape
# Out:
# (120, 163842)

# %% [markdown]
# It is time * vertices

# %% [markdown]
# Now add a useful function for zooming to a particular pycortex ROI.

# %%
flatmap_height = 2048
full_figsize = (24, 16)

full_fig = plt.figure(constrained_layout=True, figsize=full_figsize)


def zoom_to_roi(subject, roi, hem, margin=5.0):
    roi_verts = cortex.get_roi_verts(subject, roi)[roi]
    roi_map = cortex.Vertex.empty(subject)
    roi_map.data[roi_verts] = 1

    (lflatpts, lpolys), (rflatpts, rpolys) = cortex.db.get_surf(subject, "flat",
                                                                nudge=True)
    sel_pts = dict(left=lflatpts, right=rflatpts)[hem]
    roi_pts = sel_pts[np.nonzero(getattr(roi_map, hem))[0],:2]

    xmin, ymin = roi_pts.min(0) - margin
    xmax, ymax = roi_pts.max(0) + margin
    plt.axis([xmin, xmax, ymin, ymax])

# %% [markdown]
# Function for defining gaussian.

# %%
def gauss1D_cart(x, mu=0.0, sigma=1.0):
    """gauss1D_cart
    gauss1D_cart takes a 1D array x, a mean and standard deviation,
    and produces a gaussian with given parameters, with a peak of height 1.
    Parameters
    ----------
    x : numpy.ndarray (1D)
        space on which to calculate the gauss
    mu : float, optional
        mean/mode of gaussian (the default is 0.0)
    sigma : float, optional
        standard deviation of gaussian (the default is 1.0)
    Returns
    -------
    numpy.ndarray
        gaussian values at x
    """

    return np.exp(-((x-mu)**2)/(2*sigma**2))

# %% [markdown]
# Define a function for filtering the V1 vertices.

# %%
def get_candidate_mask(ROIvec,ROIval,R2vec,R2thresh,eccvec,eccthresh,idxvec):
    
    m1=ROIvec==ROIval
    m2=R2vec>R2thresh
    m3=eccvec<eccthresh

    mymask=np.logical_and(m1 == True, m2 == True)

    mymask2=np.logical_and(m3 == True, mymask == True)
    
    filtmask=np.array(idxvec[mymask2]).astype(int)
    
    pmask=np.array(mymask2.astype(float))
    pmask[pmask==0]=np.nan
    
    return filtmask, pmask

# %%
cmask=get_candidate_mask(sframeL['ROI'],1,sframeL['R2'],20,sframeL['ecc'],8,sframeL['idx'])

# %% [markdown]
# Here for instance, I take vertices with a healthy R2 and within the eccentricity range of the screen. Plot the vertices.

# %%
# %matplotlib inline
def plot_V1_mask(sub,maskdat,hem,fig):
    heavy=cortex.Vertex(maskdat,subject=sub, vmin=0, vmax=1,cmap='plasma')
    mfig=cortex.quickshow(heavy,with_curvature=True,fig=fig,with_colorbar=False)
    zoom_to_roi(sub,'V1',hem)

# %%
plot_V1_mask('02',cmask[1],'left',full_fig)
# Out:
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)

# %% [markdown]
# There are 1377 V1 positions indicated by the vertices in this mask. For each of these, we need to compute a distance matrix.

# %%
cmask[0].shape
# Out:
# (1377,)

# %% [markdown]
# Function for recovering subject surfaces from database

# %%
def get_subject_surfaces(sub,surf):
    surfs = [cortex.polyutils.Surface(*d)
    for d in cortex.db.get_surf(sub, surf)]
    return surfs

# %%
surfs=get_subject_surfaces('02','fiducial')

# %% [markdown]
# Function for recovering geodesic distances of a subset of vertices.

# %%
def get_geodesic_distance_array(surf,verts):
    dists=list()
    for vert in verts:
        dists.append(surf.geodesic_distance(vert))
    distarr=np.array(dists)
    return distarr

# %%
fdistarr=get_geodesic_distance_array(surfs[0],cmask[0])

# %% [markdown]
# We now have a numpy array, with a distance matrix for each of the V1 vertices.

# %%
fdistarr.shape
# Out:
# (1377, 163842)

# %% [markdown]
# Plot the first distance matrix.

# %%
def lightplot(sub,dat,fig):
    light=cortex.Vertex(dat,subject=sub, vmin=np.nanmin(dat), vmax=np.nanmax(dat),cmap='plasma')
    mfig=cortex.quickshow(light,with_curvature=True,fig=fig,with_colorbar=False,with_rois=False)

import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

lightplot('02',fdistarr[0,:],full_fig)

# %% [markdown]
# Now, we apply our gaussian function to the distance matrix to get gaussian patches. To get different size patches, we iterate through a list of sizes. Again, I dont go paralell here, since it seems to cause problems with big arrays like this.

# %%
nonv1inds=np.array(sframeL['idx'][sframeL['ROI']!=1]).astype(int)

# %%
def make_gaussian_patches(sizes,distarray,invmask):
    glist=list()
    for s in sizes:
        print(s)
        garray=gauss1D_cart(distarray,0,s)
        garray[:,[invmask]]=0
        glist.append(garray)
    return glist

# %%
sizes=[0.5,1,2,3,4,6,8,10]

garray=make_gaussian_patches(sizes,fdistarr,nonv1inds)
# Out:
# 0.5
# 1
# 2
# 3
# 4
# 6
# 8
# 10

# %% [markdown]
# Fo each size, we now have a gaussian centred on each vertex, stunted so it doesnt extend beyond the V1 boundary.

# %%
plot_V1_mask('02',garray[0][4,:],'left',full_fig)
# Out:
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)

# %%
plot_V1_mask('02',garray[3][4,:],'left',full_fig)
# Out:
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)

# %% [markdown]
# Now we have these gaussians we can get the weighted signal within the gaussian, by dotting the data and the gaussian and dividing by the sum.

# %%
def cf_minimal(ts_data,idx,garray):
    pooled_dat=np.dot(ts_data,garray[idx])/sum(garray[idx])
    return pooled_dat

# %% [markdown]
# Now this is the bit that can take some time.

# %%
def get_cf_timecourses(garray,ts_data,procs):
    timecourses=list()
    for g in garray:
            timecourses.append(Parallel(n_jobs=procs,verbose=1,backend='multiprocessing')(delayed(cf_minimal)(ts_data,idx,g)  for idx in range(g.shape[0])))
    timecoursearray=np.array(timecourses)
    return timecoursearray

# %%
tc_array=get_cf_timecourses(garray,BIGDATAL,15)
# Out:
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   46.0s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.3min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   45.9s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.4min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.3min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   46.3s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.3min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   46.9s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.4min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.4min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.5min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.4min finished

# %% [markdown]
# Now we have a bunch of timeseries for each patch size centred on each V1 vertex. It makes sense to zscore these so that the intercept is removed from the equation.

# %%
garray[0].shape
# Out:
# (1377, 163842)

# %%
z_tc_array=stats.zscore(tc_array, axis=2)
plt.plot(tc_array[2,2,:],'r')
plt.plot(z_tc_array[2,2,:])

# %%
garray.shape
# Out:
# (8, 1377, 163842)

# %% [markdown]
# Here, I also prepare the matrix of some prf parameters, so we can link the best fitting cf to the prf parameters.

# %%
params=np.transpose(np.vstack((np.nan_to_num(np.array(sframeL['ang'])),np.nan_to_num(np.array(sframeL['ecc'])))))

# %% [markdown]
# Now we can find the best fitting patch by dotting the zscored timeseries and the zscored array of patches and finding the maximum dot product. I also convert this to R2.

# %%
def getminparams(ts_data,ind,zattarray):
    targdat=np.squeeze(stats.zscore(ts_data[:,ind]))
    dots=np.dot(zattarray,targdat)
    indices=np.array(np.unravel_index(dots.argmax(), dots.shape))
    
    
    r2 = (dots[indices[0],indices[1]]/120)**2
    cfparams=np.concatenate((np.array(indices), np.array(r2)), axis=None)
    
    
    
    return cfparams

# %%
cfs=Parallel(n_jobs=10,verbose=1,backend='multiprocessing')(delayed(getminparams)(BIGDATAL,idx,z_tc_array)  for idx in nonv1inds)
# Out:
# [Parallel(n_jobs=10)]: Using backend MultiprocessingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=10)]: Done 1450 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=10)]: Done 5450 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=10)]: Done 11050 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=10)]: Done 18250 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=10)]: Done 27050 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=10)]: Done 37450 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=10)]: Done 49450 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=10)]: Done 63050 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=10)]: Done 78250 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=10)]: Done 95050 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=10)]: Done 113450 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=10)]: Done 133450 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=10)]: Done 155050 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=10)]: Done 160275 out of 160275 | elapsed:  3.7min finished

# %% [markdown]
# Considering that everything outside of V1 is being fit, that didnt take very long at all.

# %%
cfarray=np.array(cfs)
cfarray
# Out:
# array([[   4.        ,  173.        ,    0.26682942],
#        [   0.        ,   75.        ,    0.33794653],
#        [   2.        , 1304.        ,    0.06737291],
#        ...,
#        [   0.        ,  506.        ,    0.07156207],
#        [   2.        ,  406.        ,    0.04791252],
#        [   0.        ,  406.        ,    0.04916396]])

# %%
idxarray=cfarray[:,:2].astype(int)

# %%
R2arrayL=np.zeros(163842)
idx1L=np.zeros(163842)
idx2L=np.zeros(163842)

# %%
R2arrayL[nonv1inds]=cfarray[:,2]
idx1L[nonv1inds]=cfarray[:,0]
idx2L[nonv1inds]=cfarray[:,1]

# %%
z_tc_array.shape
# Out:
# (8, 1377, 120)

# %% [markdown]
# Returned is an array. The first two columns are the indices of the best fitting gaussian (first column is cf size, second column is cf vertex). The last column is the R2. Now plot the cf model fits.

# %%
def alphaplot(sub,dat,R2,vmin,vmax,thresh,fig):
    light=cortex.Vertex2D(dat,R2,subject=sub, vmin=vmin, vmax=vmax,vmin2=thresh,vmax2=1,cmap='plasma_alpha')
    mfig=cortex.quickshow(light,with_curvature=True,fig=fig)
    return mfig
R2p=alphaplot('02',R2arrayL,R2arrayL,.15,1,.15,full_fig)
# Out:
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)

# %%
flat_path='/Volumes/BAHAMUT/OUTPUT/FULL/FLATMAPS/CF'

# %%
R2p.savefig(os.path.join(flat_path,'R2'+'_flat.png'), dpi=300, facecolor='w', edgecolor='w',orientation='portrait', papertype=None, format='png',transparent=False, bbox_inches=None, pad_inches=0.1,
    frameon=None)

# %% [markdown]
# Convert the size indices to the sizes they actually correspond to.

# %%
sarrayL=np.zeros(163842,dtype=np.float64)
sarrayL[nonv1inds]=cfarray[:,0]

for s in range(8):    
    sarrayL=np.where(sarrayL==s, sizes[s], sarrayL)
    
sp=alphaplot('02',sarrayL,R2arrayL,0,10,.15,full_fig)
# Out:
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)

# %%
sp.savefig(os.path.join(flat_path,'sigma'+'_flat.png'), dpi=300, facecolor='w', edgecolor='w',orientation='portrait', papertype=None, format='png',transparent=False, bbox_inches=None, pad_inches=0.1,
    frameon=None)

# %%
garray.shape
# Out:
# (8, 1377, 163842)

# %%
import matplotlib
# %matplotlib qt

matplotlib.use('Qt5Agg',warn=False, force=True)

fig, ax = plt.subplots(figsize=full_figsize)
import cortex as cx

dat=sarrayL
sub='02'

light=cortex.Vertex(dat,subject=sub, vmin=np.nanmin(dat), vmax=np.nanmax(dat),cmap='plasma')

cx.quickshow(light, with_rois=True, with_curvature=True,fig=ax, with_colorbar=False)

flatmap_height = 2048
mask, extents = cx.quickflat.utils.get_flatmask(sub, height=flatmap_height)
vc = cx.quickflat.utils._make_vertex_cache(subject, height=flatmap_height)

mask_index = np.zeros(mask.shape)
mask_index[mask] = np.arange(mask.sum())
    

def draw_vertex_plots(vertex,hem):
    
    fig2, ax2 = plt.subplots()
    fig3, ax3 = plt.subplots()    
    
    ax2.clear()
    ax2.axhline(0, color='black', lw=0.25)
    if hem =='l':
        
        ax2.plot(stats.zscore(BIGDATAL[:,vertex]))
        
        ax2.plot(z_tc_array[int(idx1L[vertex]),int(idx2L[vertex]),:])
        
        #ax2.plot(np.array(longframe[longframe['idx']==vertex]['pred'])[0:119])
        #ax2.plot(np.array(longframe[longframe['idx']==vertex]['data'])[0:119])        
        #prf = generate_og_receptive_field(np.array(df[df['idx']==vertex]['X'])[0],np.array(df[df['idx']==vertex]['Y'])[0],
        #np.array(df[df['idx']==vertex]['sigma'])[0],stimulus.deg_x,stimulus.deg_y)
        
        
    else:
        ax2.plot(np.array(longframe[longframe['idx']==vertex]['pred'])[120:238])
        ax2.plot(np.array(longframe[longframe['idx']==vertex]['data'])[120:238])
        prf = generate_og_receptive_field(np.array(df[df['idx']==vertex]['X'])[1],np.array(df[df['idx']==vertex]['Y'])[1],
        np.array(df[df['idx']==vertex]['sigma'])[1],stimulus.deg_x,stimulus.deg_y)
    
    ax3.clear()
    plot_V1_mask('02',garray[int(idx1L[vertex]),int(idx2L[vertex]),:],'left',ax3)
    plt.draw()



def onclick(event):
    print('%s click: button=%d, x=%d, y=%d, xdata=%f, ydata=%f' %
          ('double' if event.dblclick else 'single', event.button,
           event.x, event.y, event.xdata, event.ydata))
    xmin, xmax = ax.get_xbound()
    ax_xrange = xmax-xmin
    ymin, ymax = ax.get_ybound()
    ax_yrange = ymax-ymin

    rel_x = int(mask.shape[0] * (event.xdata-xmin)/ax_xrange)
    rel_y = int(mask.shape[1] * (event.ydata-ymin)/ax_yrange)
    clicked_pixel = (rel_x, rel_y)
    
    if event.xdata<0:
        hem='l'
        clicked_vertex = vc[int(mask_index[clicked_pixel[0], clicked_pixel[1]])]
        vindex=clicked_vertex.indices[0]
    else:
        hem='r'
        clicked_vertex = vc[int(mask_index[clicked_pixel[0], clicked_pixel[1]])]
        vindex=clicked_vertex.indices[0]-163842
    
    print(clicked_pixel)
    print(clicked_vertex)
    print(vindex)
    draw_vertex_plots(vindex,hem)

cid = fig.canvas.mpl_connect('button_press_event', onclick)
# Out:
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)
# single click: button=1, x=813, y=402, xdata=-60.352901, ydata=-41.839650
# (2102, 744)
#   (0, 66437)	1.0
# 66437
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)
# single click: button=1, x=847, y=471, xdata=-42.435549, ydata=-5.477967
# (2222, 987)
#   (0, 87819)	1.0
# 87819
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)
# single click: button=1, x=758, y=404, xdata=-89.336851, ydata=-40.785688
# (1908, 751)
#   (0, 25439)	1.0
# 25439
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)
# single click: button=1, x=831, y=385, xdata=-50.867244, ydata=-50.798326
# (2165, 684)
#   (0, 75652)	1.0
# 75652
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)
# single click: button=1, x=832, y=386, xdata=-50.340263, ydata=-50.271345
# (2169, 688)
#   (0, 34311)	1.0
# 34311
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)
# single click: button=1, x=826, y=480, xdata=-53.502149, ydata=-0.735138
# (2148, 1019)
#   (0, 135914)	1.0
# 135914
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)

# %% [markdown]
# Now,I can use the index of the best fitting cf to recover the prf parameters within the cf.
#
# It is possible to do this with advanced indexing (i.e. using an array of indexes to index another array) but my computer runs out of memory when I do this. Therefore I just do everything in a big loop.

# %%
garray=np.array(garray)

# %%
idxarray=cfarray[:,:2].astype(int)

# %%
def get_prf_params(garray,idxarray,paramarray,idx):
    prfparams=np.dot(garray[tuple(idxarray[idx,:])],paramarray)/sum(garray[tuple(idxarray[idx,:])])
    return prfparams

# %%
prf=Parallel(n_jobs=20,verbose=1,backend='multiprocessing')(delayed(get_prf_params)(garray,idxarray,params,idx)  for idx in range(idxarray.shape[0]))
# Out:
# [Parallel(n_jobs=20)]: Using backend MultiprocessingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=20)]: Done 160 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=20)]: Done 410 tasks      | elapsed:   34.6s
# [Parallel(n_jobs=20)]: Done 760 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=20)]: Done 1210 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=20)]: Done 1760 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=20)]: Done 2410 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=20)]: Done 3160 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=20)]: Done 4010 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=20)]: Done 4960 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=20)]: Done 6010 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=20)]: Done 7160 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=20)]: Done 8410 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=20)]: Done 9760 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=20)]: Done 11210 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=20)]: Done 12760 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=20)]: Done 14410 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=20)]: Done 16160 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=20)]: Done 18010 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=20)]: Done 19960 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=20)]: Done 22010 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=20)]: Done 24160 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=20)]: Done 26410 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=20)]: Done 28760 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=20)]: Done 31210 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=20)]: Done 33760 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=20)]: Done 36410 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=20)]: Done 39160 tasks      | elapsed: 19.1min
# [Parallel(n_jobs=20)]: Done 42010 tasks      | elapsed: 20.6min
# [Parallel(n_jobs=20)]: Done 44960 tasks      | elapsed: 22.2min
# [Parallel(n_jobs=20)]: Done 48010 tasks      | elapsed: 23.8min
# [Parallel(n_jobs=20)]: Done 51160 tasks      | elapsed: 25.4min
# [Parallel(n_jobs=20)]: Done 54410 tasks      | elapsed: 27.2min
# [Parallel(n_jobs=20)]: Done 57760 tasks      | elapsed: 29.0min
# [Parallel(n_jobs=20)]: Done 61210 tasks      | elapsed: 30.9min
# [Parallel(n_jobs=20)]: Done 64760 tasks      | elapsed: 32.9min
# [Parallel(n_jobs=20)]: Done 68410 tasks      | elapsed: 34.9min
# [Parallel(n_jobs=20)]: Done 72160 tasks      | elapsed: 37.0min
# [Parallel(n_jobs=20)]: Done 76010 tasks      | elapsed: 39.1min
# [Parallel(n_jobs=20)]: Done 79960 tasks      | elapsed: 41.3min
# [Parallel(n_jobs=20)]: Done 84010 tasks      | elapsed: 43.5min
# [Parallel(n_jobs=20)]: Done 88160 tasks      | elapsed: 45.7min
# [Parallel(n_jobs=20)]: Done 92410 tasks      | elapsed: 47.9min
# [Parallel(n_jobs=20)]: Done 96760 tasks      | elapsed: 50.2min
# [Parallel(n_jobs=20)]: Done 101210 tasks      | elapsed: 52.5min
# [Parallel(n_jobs=20)]: Done 105760 tasks      | elapsed: 54.9min
# [Parallel(n_jobs=20)]: Done 110410 tasks      | elapsed: 57.3min
# [Parallel(n_jobs=20)]: Done 115160 tasks      | elapsed: 59.8min
# [Parallel(n_jobs=20)]: Done 120010 tasks      | elapsed: 62.2min
# [Parallel(n_jobs=20)]: Done 124960 tasks      | elapsed: 64.8min
# [Parallel(n_jobs=20)]: Done 130010 tasks      | elapsed: 67.3min
# [Parallel(n_jobs=20)]: Done 135160 tasks      | elapsed: 69.8min
# [Parallel(n_jobs=20)]: Done 140410 tasks      | elapsed: 72.3min
# [Parallel(n_jobs=20)]: Done 145760 tasks      | elapsed: 75.0min
# [Parallel(n_jobs=20)]: Done 151210 tasks      | elapsed: 77.7min
# [Parallel(n_jobs=20)]: Done 156760 tasks      | elapsed: 80.5min
# [Parallel(n_jobs=20)]: Done 160275 out of 160275 | elapsed: 82.2min finished

# %%
prf_arr=np.array(prf)

# %%
angL=np.zeros(163842,dtype=np.float64)
angL[nonv1inds]=prf_arr[:,0]
angL[angL==0]=np.nan
ap=alphaplot('02',angL,R2arrayL,0,180,.15,full_fig)


ap.savefig(os.path.join(flat_path,'ang'+'_flat.png'), dpi=300, facecolor='w', edgecolor='w',orientation='portrait', papertype=None, format='png',transparent=False, bbox_inches=None, pad_inches=0.1,
    frameon=None)
# Out:
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)

# %%
eccL=np.zeros(163842,dtype=np.float64)
eccL[nonv1inds]=prf_arr[:,1]
eccL[eccL==0]=np.nan
ep=alphaplot('02',eccL,R2arrayL,0,8,.15,full_fig)


ep.savefig(os.path.join(flat_path,'ecc'+'_flat.png'), dpi=300, facecolor='w', edgecolor='w',orientation='portrait', papertype=None, format='png',transparent=False, bbox_inches=None, pad_inches=0.1,
    frameon=None)
# Out:
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)

# %% [markdown]
# ## Nonlinear Stuff

# %% [markdown]
# "First pass; I think you’d have to not z-score time courses but do everything in % signal change, and fit not using a dot product but with a GLM that incorporates an intercept."

# %% [markdown]
# As far as I can determine, All I should have to do is use a power transformation to change the gaussian rf model. For instance to the power of 1 is no transformation and to the power of <1 is a compressive cf.

# %% [markdown]
# Let's take my mid-sized gaussian fields (4 mm)

# %%
garray.shape
# Out:
# (8, 1377, 163842)

# %%
testfields=np.copy(garray[4,:,:])

# %% [markdown]
# And apply 5 different power transformations to them.

# %%
nonlinearities=[1,0.2,0.1,0.05,0.01]

# %%
css_testfields=list()
for nl in nonlinearities:
    print(nl)
    css_testfields.append(np.power(testfields,nl))
# Out:
# 1
# 0.2
# 0.1
# 0.05
# 0.01

# %% [markdown]
# Plot the linear model weightings against those of the most compressive model.

# %%
plt.plot(css_testfields[0][0,:],css_testfields[4][0,:],'*')
plt.plot(css_testfields[0][0,:],css_testfields[3][0,:],'*')
plt.plot(css_testfields[0][0,:],css_testfields[2][0,:],'*')
plt.plot(css_testfields[0][0,:],css_testfields[1][0,:],'*')
plt.plot(css_testfields[0][0,:],css_testfields[0][0,:],'*')

# %% [markdown]
# The behavior is that a signal with a low weighting for the linear model is given a higher weighting in the compressive model. In other words, smaller amouts of overlap between the stimulus and the cf give rise to larger responses.

# %%
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1])
ax0 = plt.subplot(gs[0])
plot_V1_mask('02',css_testfields[0][4,:],'left',ax0)
ax1 = plt.subplot(gs[1])
plot_V1_mask('02',css_testfields[3][4,:],'left',ax1)
# Out:
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)
# Background RRGGBBAA: ffffff00
# Area 0:0:2358.35:1024 exported to 2358 x 1024 pixels (96 dpi)

# %% [markdown]
# Now we have these compressive fields, we can dot them with our data to see the different ways in which they respond.

# %%
def get_cf_timecourses(garray,ts_data,procs):
    timecourses=list()
    for g in garray:
            timecourses.append(Parallel(n_jobs=procs,verbose=1,backend='multiprocessing')(delayed(cf_minimal)(ts_data,idx,g)  for idx in range(g.shape[0])))
    timecoursearray=np.array(timecourses)
    return timecoursearray

# %%
css_tc_array=get_cf_timecourses(css_testfields,BIGDATAL,15)
# Out:
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   48.6s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.3min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.3min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.3min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.4min finished
# [Parallel(n_jobs=15)]: Using backend MultiprocessingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=15)]: Done 770 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=15)]: Done 1220 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 1377 out of 1377 | elapsed:  1.4min finished

# %%
css_tc_array.shape
# Out:
# (5, 1377, 120)

# %%
plt.plot(css_tc_array[0,4,:])
plt.plot(css_tc_array[4,4,:],'r')

# %%
def fitter(EV,DV):
    regressor = LinearRegression()
    slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(EV, DV)
    r2=r_value**2
    return intercept,slope, r2

# %% [markdown]
# If we have to fit linear models to all of these combinations (i.e. we cant simply take the dot product), I would like to see what this involves. In other words, for each vertex, what number of combinations we will need to fit.

# %%
import itertools

# %% [markdown]
# For instance, with 5 nonlinearities, 8 cf sizes and 1377 v1 vertices, this implies fitting 55,080 models for each vertex.

# %%
paramlist=list(itertools.product(cmask[0], sizes,nonlinearities))

# %%
len(paramlist)
# Out:
# 55080

# %% [markdown]
# In turn, we need to multiply this by the number of vertices there are to fit.

# %%
nonv1inds.shape[0]*len(paramlist)
# Out:
# 8827947000

# %% [markdown]
# That's a big number.

# %%
test=np.copy(garray)

# %%
garray.shape
# Out:
# (8, 1377, 163842)

# %%
from scipy.stats import linregress

# %%
tc_array.shape

new_arr = tc_array.reshape(-1, tc_array.shape[-1])

# %%
new_arr.shape[0]
# Out:
# 11016

# %%
def fitter(dat,ind,tarray):
    results=Parallel(n_jobs=20,verbose=1,backend='multiprocessing')(delayed(linregress)(tarray[idx],dat[:,ind])  for idx in range(tarray.shape[0]))
    return results

# %%
var=fitter(BIGDATAL,2,new_arr)
# Out:
# [Parallel(n_jobs=20)]: Using backend MultiprocessingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 600 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 10560 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=20)]: Done 11016 out of 11016 | elapsed:    0.5s finished

# %%
varray=np.array(var)

# %%
varray
# Out:
# array([[-0.00323488,  0.        , -0.02866948,  0.75592601,  0.01038292],
#        [ 0.01622179,  0.        ,  0.05105071,  0.57975655,  0.02921389],
#        [-0.007068  ,  0.        , -0.02684993,  0.77097474,  0.02422454],
#        ...,
#        [ 0.03343728,  0.        ,  0.07116608,  0.43987424,  0.0431434 ],
#        [ 0.03648391,  0.        ,  0.07400229,  0.42181775,  0.04526086],
#        [ 0.03712958,  0.        ,  0.07376391,  0.42331868,  0.04621153]])
